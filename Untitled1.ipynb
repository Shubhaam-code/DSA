# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhaam-code/DSA/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Shubham Narayan"

print(name.split())
print(name.split("a"))
print(name.split(","))

print("Shubham\nNarayan") #\n next line
print("Hello\rWorld") #Carriage return

print("SHubham \t Narayan")
print("Shubham\tNarayan")
# Out:
# ['Shubham', 'Narayan']
# ['Shubh', 'm N', 'r', 'y', 'n']
# ['Shubham Narayan']
# Shubham
# Narayan
# World
# SHubham 	 Narayan
# Shubham	Narayan

# %% [markdown]
# #function

# %%
name="shubham"
paragraph="python python is good language for beginner it is easy understable"
print(len(name))
print(name.lower())
print(name.upper())
print(paragraph.title())
print(paragraph.capitalize())
print(paragraph.count("a"))
print(paragraph.count(" "))
print(paragraph.replace("python","java"))
print(name.isnumeric())
print(name.find("m"))
print(paragraph.count("python")) #Koi character/word kitni baar aaya:
print(paragraph.count("o"))

s = "Python"

print(s.startswith("Py"))
print(s.endswith("on"))
# Out:
# 7
# shubham
# SHUBHAM
# Python Python Is Good Language For Beginner It Is Easy Understable
# Python python is good language for beginner it is easy understable
# 4
# 10
# java java is good language for beginner it is easy understable
# False
# 6
# 2
# 5

# %% [markdown]
# SPLIT FUNCTION

# %%
para= "India Won world cup in 2011 and after that they never won any world cup only single time they goes in final but defeated by australia in 2023"
number = "12345"

print(number.split())
print(para.split())
print(para.split("a"))


para1 = "banana"
print(para1.split("a")) #Python bolta hai: "Bhai, separator ke baad koi text nahi hai, to empty string '' store kar deta hoon."
s = "apple,banana,mango,"

print(s.split(","))
# Out:
# ['12345']
# ['India', 'Won', 'world', 'cup', 'in', '2011', 'and', 'after', 'that', 'they', 'never', 'won', 'any', 'world', 'cup', 'only', 'single', 'time', 'they', 'goes', 'in', 'final', 'but', 'defeated', 'by', 'australia', 'in', '2023']
# ['Indi', ' Won world cup in 2011 ', 'nd ', 'fter th', 't they never won ', 'ny world cup only single time they goes in fin', 'l but defe', 'ted by ', 'ustr', 'li', ' in 2023']
# ['b', 'n', 'n', '']
# ['apple', 'banana', 'mango', '']

# %% [markdown]
# Join

# %%
s=["I","LOVE","MY","DAD"]
print( " ".join(s))
print( "@".join(s))
# Out:
# I LOVE MY DAD
# I@LOVE@MY@DAD

# %% [markdown]
# **`Function of string`**

# %%
s = "12345"

print(s.isdigit())
print("Python".isalpha())      # True
print("Python123".isalpha())   # False

s = "PyThOn"

print(s.swapcase())
# Out:
# True
# True
# False
# pYtHoN
